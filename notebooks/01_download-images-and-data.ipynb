# %%
# %load_ext autoreload
# %autoreload 2

from dateutil import parser
from zoneinfo import ZoneInfo
from datetime import timezone, timedelta

from pynims.workflows import download_images_for_camera
from pynims.client import NIMSClient
from pynims.utils import convert_nims_image_name_to_utc_date

import dataretrieval.nwis as nwis

import pandas as pd
from IPython.display import display

# %%
# Set some initial parameters
site = '02110525'
camera_id = 'SC_Waccamaw_River_at_SC_22_below_Longs'
run_name = 'event_2025-08-14'
max_results = 2000  # None

run_dir = f'cameras/{camera_id}/{run_name}'
save_dir = f'{run_dir}/images'

start_all = '2025-08-14'  # local time
end_all = '2025-09-17'  # local time

start_event = '2025-08-14 15:30'  # local time
end_event = '2025-09-16 19:45'  # local time

use_event_times = True

allowable_im_data_time_diff = 60  # in seconds

# Load existing run config if available (for reproducibility)
import json, os
_config_path = f'{run_dir}/run_config.json'
_existing_config = {}
if os.path.exists(_config_path):
    with open(_config_path) as f:
        _existing_config = json.load(f)
    print(f'Loaded existing config from {_config_path}')

# %%
with NIMSClient() as client:
    tz = client.get_camera_attribute(camera_id, "tz")
print(f"==>> tz: {tz}")

if use_event_times:
    start = parser.parse(start_event)
    end = parser.parse(end_event)
else:
    start = parser.parse(start_all)
    end = parser.parse(end_all)


# Attach known timezone (if not already present)
if start.tzinfo is None:
    start = start.replace(tzinfo=ZoneInfo(tz))
if end.tzinfo is None:
    end = end.replace(tzinfo=ZoneInfo(tz))

# Convert to UTC
start = start.astimezone(timezone.utc)
print(f"==>> start (utc): {start}")
end = end.astimezone(timezone.utc)
print(f"==>> end (utc): {end}")
# Out:
# ==>> tz: US/Eastern
# ==>> start (utc): 2025-08-14 19:30:00+00:00
# ==>> end (utc): 2025-09-16 23:45:00+00:00

# %%
with NIMSClient() as client:
    image_list = client.get_image_list(
        camera_id, start, end, recursive=None, max_results=max_results
    )
print(f"==>> image_list: {image_list}")
print(f"==>> len(image_list): {len(image_list)}")
# Out:
# ==>> image_list: ['SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T19-30-02Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T19-45-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T20-00-07Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T20-15-02Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T20-30-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T20-45-04Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T21-00-08Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T21-15-22Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T21-30-04Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T21-45-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T22-00-06Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T22-15-22Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T22-30-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T22-45-02Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T23-00-04Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T23-15-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T23-30-08Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T23-45-02Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T00-00-06Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T00-15-03Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T00-30-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T10-15-23Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T10-30-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T10-45-23Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T11-00-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T11-15-25Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T11-30-02Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T11-45-22Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T12-00-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T12-15-23Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T12-30-04Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T12-45-02Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T13-00-06Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T13-15-04Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T13-30-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T13-45-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T14-00-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T14-15-03Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T14-30-02Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T14-45-22Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T15-00-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T15-15-22Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T15-30-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T15-45-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T16-00-14Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T16-15-02Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T16-30-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T16-45-23Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T17-00-05Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T17-15-02Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T17-30-02Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T17-45-04Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T18-00-04Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T18-15-08Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T18-30-04Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T18-45-04Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-15T19-00-25Z.jpg', 'SC_Waccamaw_River_at_SC_22_below_Longs___2025-08 ...
# ==>> len(image_list): 1825

# %%
keep_every_nth_image = _existing_config.get('keep_every_nth_image', 20) # set to 1 to keep all images
image_list = image_list[0::keep_every_nth_image]
print(f"==>> len(image_list) after keeping every {keep_every_nth_image}th image: {len(image_list)}")
# Out:
# ==>> len(image_list) after keeping every 20th image: 92

# %%
download_images_for_camera(camera_id, start, end, max_results=max_results, save_dir=save_dir, image_list=image_list)
# Out:
# image # 1 of 92
# SC_Waccamaw_River_at_SC_22_below_Longs___2025-08-14T19-30-02Z.jpg already exists -- skipping
# image # 2 of 92
# image # 3 of 92
# image # 4 of 92
# image # 5 of 92
# image # 6 of 92
# image # 7 of 92
# image # 8 of 92
# image # 9 of 92
# image # 10 of 92
# image # 11 of 92
# image # 12 of 92
# image # 13 of 92
# image # 14 of 92
# image # 15 of 92
# image # 16 of 92
# image # 17 of 92
# image # 18 of 92
# image # 19 of 92
# image # 20 of 92
# image # 21 of 92
# image # 22 of 92
# image # 23 of 92
# image # 24 of 92
# image # 25 of 92
# image # 26 of 92
# image # 27 of 92
# image # 28 of 92
# image # 29 of 92
# image # 30 of 92
# image # 31 of 92
# image # 32 of 92
# image # 33 of 92
# image # 34 of 92
# image # 35 of 92
# image # 36 of 92
# image # 37 of 92
# image # 38 of 92
# image # 39 of 92
# image # 40 of 92
# image # 41 of 92
# image # 42 of 92
# image # 43 of 92
# image # 44 of 92
# image # 45 of 92
# image # 46 of 92
# image # 47 of 92
# image # 48 of 92
# image # 49 of 92
# image # 50 of 92
# image # 51 of 92
# image # 52 of 92
# image # 53 of 92
# image # 54 of 92
# image # 55 of 92
# image # 56 of 92
# image # 57 of 92
# image # 58 of 92
# image # 59 of 92
# image # 60 of 92
# image # 61 of 92
# image # 62 of 92
# image # 63 of 92
# image # 64 of 92
# image # 65 of 92
# image # 66 of 92
# image # 67 of 92
# image # 68 of 92
# image # 69 of 92
# image # 70 of 92
# image # 71 of 92
# image # 72 of 92
# image # 73 of 92
# image # 74 of 92
# image # 75 of 92
# image # 76 of 92
# image # 77 of 92
# image # 78 of 92
# image # 79 of 92
# image # 80 of 92
# image # 81 of 92
# image # 82 of 92
# image # 83 of 92
# image # 84 of 92
# image # 85 of 92
# image # 86 of 92
# image # 87 of 92
# image # 88 of 92
# image # 89 of 92
# image # 90 of 92
# image # 91 of 92
# image # 92 of 92

# %%
image_times = [convert_nims_image_name_to_utc_date(image) for image in image_list]
print([dt.isoformat() for dt in image_times])
print(f"==>> len(image_times): {len(image_times)}")
# Out:
# ['2025-08-14T19:30:02+00:00', '2025-08-15T00:30:05+00:00', '2025-08-15T15:00:05+00:00', '2025-08-15T20:00:03+00:00', '2025-08-16T10:30:16+00:00', '2025-08-16T16:30:02+00:00', '2025-08-16T21:30:09+00:00', '2025-08-17T12:15:05+00:00', '2025-08-17T17:15:04+00:00', '2025-08-17T22:15:02+00:00', '2025-08-18T13:00:08+00:00', '2025-08-18T18:00:15+00:00', '2025-08-18T23:00:06+00:00', '2025-08-19T14:00:21+00:00', '2025-08-19T19:00:41+00:00', '2025-08-20T00:00:10+00:00', '2025-08-20T15:00:21+00:00', '2025-08-20T20:00:20+00:00', '2025-08-21T11:00:20+00:00', '2025-08-21T17:30:02+00:00', '2025-08-21T22:30:13+00:00', '2025-08-22T13:30:05+00:00', '2025-08-22T18:30:02+00:00', '2025-08-22T23:30:04+00:00', '2025-08-23T14:30:02+00:00', '2025-08-23T19:30:05+00:00', '2025-08-24T10:30:02+00:00', '2025-08-24T15:30:04+00:00', '2025-08-24T20:30:05+00:00', '2025-08-25T11:30:02+00:00', '2025-08-25T16:30:02+00:00', '2025-08-25T21:30:05+00:00', '2025-08-26T12:30:04+00:00', '2025-08-26T17:30:02+00:00', '2025-08-26T22:30:04+00:00', '2025-08-27T13:30:04+00:00', '2025-08-27T18:30:05+00:00', '2025-08-27T23:30:05+00:00', '2025-08-28T14:30:09+00:00', '2025-08-28T19:30:04+00:00', '2025-08-29T10:45:02+00:00', '2025-08-29T15:45:10+00:00', '2025-08-29T20:45:03+00:00', '2025-08-30T12:00:13+00:00', '2025-08-30T17:00:04+00:00', '2025-08-30T22:00:03+00:00', '2025-08-31T13:15:04+00:00', '2025-08-31T18:15:05+00:00', '2025-08-31T23:15:05+00:00', '2025-09-01T14:30:02+00:00', '2025-09-01T19:30:04+00:00', '2025-09-02T10:45:04+00:00', '2025-09-02T15:45:02+00:00', '2025-09-02T20:45:10+00:00', '2025-09-03T12:00:04+00:00', '2025-09-03T17:00:09+00:00', '2025-09-03T22:00:04+00:00', '2025-09-04T13:15:03+00:00', '2025-09-04T18:15:08+00:00', '2025-09-04T23:15:05+00:00', '2025-09-05T14:30:04+00:00', '2025-09-05T19:30:02+00:00', '2025-09-06T10:45:02+00:00', '2025-09-06T15:45:23+00:00', '2025-09-06T20:45:05+00:00', '2025-09-07T12:00:06+00:00', '2025-09-07T17:00:05+00:00', '2025-09-07T22:00:08+00:00', '2025-09-08T13:30:07+00:00', '2025-09-08T18:30:16+00:00', '2025-09-08T23:30:08+00:00', '2025-09-09T15:15:03+00:00', '2025-09-09T20:15:05+00:00', '2025-09-10T12:00:08+00:00', '2025-09-10T17:00:06+00:00', '2025-09-10T22:00:26+00:00', '2025-09-11T13:45:24+00:00', '2025-09-11T18:45:05+00:00', '2025-09-11T23:45:02+00:00', '2025-09-12T15:30:04+00:00', '2025-09-12T20:30:05+00:00', '2025-09-13T12:15:03+00:00', '2025-09-13T17:15:05+00:00', '2025-09-13T22:15:02+00:00', '2025-09-14T14:00:08+00:00', '2025-09-14T19:00:04+00:00', '2025-09-15T10:45:02+00:00', '2025-09-15T15:45:05+00:00', '2025-09-15T20:45:02+00:00', '2025-09-16T12:30:03+00:00', '2025-09-16T17:30:03+00:00', '2025-09-16T22:30:04+00:00']
# ==>> len(image_times): 92

# %%
# Data request requires start and end date in format YYYY-MM-DD
start_minus_one_day = (start - timedelta(days=1)).replace(hour=0, minute=0, second=0, microsecond=0).strftime("%Y-%m-%d")
end_plus_one_day = (end + timedelta(days=1)).replace(hour=0, minute=0, second=0, microsecond=0).strftime("%Y-%m-%d")

# Get data
data_df = nwis.get_record(sites=site, service='iv', start=start_minus_one_day, end=end_plus_one_day)

# Filter data to our original range
mask = (data_df.index >= start) & (data_df.index <= end)
data_df = data_df.loc[mask]

display(data_df)
# Out:
#                             site_no  00065 00065_cd  63160 63160_cd
# datetime
# 2025-08-14 19:30:00+00:00  02110525  21.67        A  12.91        P
# 2025-08-14 19:45:00+00:00  02110525  21.66        A  12.90        P
# 2025-08-14 20:00:00+00:00  02110525  21.68        A  12.92        P
# 2025-08-14 20:15:00+00:00  02110525  21.69        A  12.93        P
# 2025-08-14 20:30:00+00:00  02110525  21.68        A  12.92        P
# ...                             ...    ...      ...    ...      ...
# 2025-09-16 22:45:00+00:00  02110525  10.59        A   1.83        P
# 2025-09-16 23:00:00+00:00  02110525  10.57        A   1.81        P
# 2025-09-16 23:15:00+00:00  02110525  10.55        A   1.79        P
# 2025-09-16 23:30:00+00:00  02110525  10.53        A   1.77        P
# 2025-09-16 23:45:00+00:00  02110525  10.51        A   1.75        P
#
# [3186 rows x 5 columns]

# %%
image_df = pd.DataFrame({"image_times": image_times, "image_names": image_list})
display(image_df)
# Out:
#                  image_times  \
# 0  2025-08-14 19:30:02+00:00
# 1  2025-08-15 00:30:05+00:00
# 2  2025-08-15 15:00:05+00:00
# 3  2025-08-15 20:00:03+00:00
# 4  2025-08-16 10:30:16+00:00
# ..                       ...
# 87 2025-09-15 15:45:05+00:00
# 88 2025-09-15 20:45:02+00:00
# 89 2025-09-16 12:30:03+00:00
# 90 2025-09-16 17:30:03+00:00
# 91 2025-09-16 22:30:04+00:00
#
#                                           image_names
# 0   SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 1   SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 2   SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 3   SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 4   SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# ..                                                ...
# 87  SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 88  SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 89  SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 90  SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 91  SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
#
# [92 rows x 2 columns]

# %%
merged = pd.merge_asof(
    image_df.sort_values("image_times"),
    data_df.reset_index().rename(columns={"datetime": "data_times"}),
    left_on="image_times",
    right_on="data_times",
    direction="nearest",
)

merged["time_diff_sec"] = (merged["image_times"] - merged["data_times"]).abs().dt.total_seconds()
filtered = merged[merged["time_diff_sec"] <= allowable_im_data_time_diff]

display(merged)
# Out:
#                  image_times  \
# 0  2025-08-14 19:30:02+00:00
# 1  2025-08-15 00:30:05+00:00
# 2  2025-08-15 15:00:05+00:00
# 3  2025-08-15 20:00:03+00:00
# 4  2025-08-16 10:30:16+00:00
# ..                       ...
# 87 2025-09-15 15:45:05+00:00
# 88 2025-09-15 20:45:02+00:00
# 89 2025-09-16 12:30:03+00:00
# 90 2025-09-16 17:30:03+00:00
# 91 2025-09-16 22:30:04+00:00
#
#                                           image_names  \
# 0   SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 1   SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 2   SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 3   SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 4   SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# ..                                                ...
# 87  SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 88  SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 89  SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 90  SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
# 91  SC_Waccamaw_River_at_SC_22_below_Longs___2025-...
#
#                   data_times   site_no  00065 00065_cd  63160 63160_cd  \
# 0  2025-08-14 19:30:00+00:00  02110525  21.67        A  12.91        P
# 1  2025-08-15 00:30:00+00:00  02110525  21.70        A  12.94        P
# 2  2025-08-15 15:00:00+00:00  02110525  21.74        A  12.98        P
# 3  2025-08-15 20:00:00+00:00  02110525  21.74        A  12.98        P
# 4  2025-08-16 10:30:00+00:00  02110525  21.73        A  12.97        P
# ..                       ...       ...    ...      ...    ...      ...
# 87 2025-09-15 15:45:00+00:00  02110525  10.97        A   2.21        P
# 88 2025-09-15 20:45:00+00:00  02110525  10.85        A   2.09        P
# 89 2025-09-16 12:30:00+00:00  02110525  10.75        A   1.99        P
# 90 2025-09-16 17:30:00+00:00  02110525  10.78        A   2.02        P
# 91 2025-09-16 22:30:00+00:00  02110525  10.61        A   1.85        P
#
#     time_diff_sec
# 0             2.0
# 1             5.0
# 2             5.0
# 3             3.0
# 4            16.0
# ..            ...
# 87            5.0
# 88            2.0
# 89            3.0
# 90            3.0
# 91            4.0
#
# [92 rows x 9 columns]

# %%
merged.to_csv(f'{run_dir}/images_and_data.csv')

# %%
run_config = {
    "camera_id": camera_id,
    "site": site,
    "run_name": run_name,
    "start_all": start_all,
    "end_all": end_all,
    "start_event": start_event,
    "end_event": end_event,
    "use_event_times": use_event_times,
    "max_results": max_results,
    "keep_every_nth_image": keep_every_nth_image,
    "allowable_im_data_time_diff": allowable_im_data_time_diff,
}

os.makedirs(run_dir, exist_ok=True)
config_path = f'{run_dir}/run_config.json'
with open(config_path, 'w') as f:
    json.dump(run_config, f, indent=2)

print(f"Run config saved to {config_path}")
# Out:
# Run config saved to cameras/SC_Waccamaw_River_at_SC_22_below_Longs/event_2025-08-14/run_config.json
